# %%
import pandas as pd

# %%
sheet1 = pd.read_excel('movies.xls', sheet_name='1900s')
sheet2 = pd.read_excel('movies.xls', sheet_name='2000s')

movies = pd.concat([sheet1, sheet2])

# %%
movies.head(10)
# Out:
#                                                Title  Year  \
# 0  Intolerance: Love's Struggle Throughout the Ages   1916
# 1                    Over the Hill to the Poorhouse   1920
# 2                                    The Big Parade   1925
# 3                                        Metropolis   1927
# 4                                     Pandora's Box   1929
# 5                               The Broadway Melody   1929
# 6                                     Hell's Angels   1930
# 7                                A Farewell to Arms   1932
# 8                                       42nd Street   1933
# 9                                She Done Him Wrong   1933
#
#                                  Genres Language  Country Content Rating  \
# 0                     Drama|History|War      NaN      USA      Not Rated
# 1                           Crime|Drama      NaN      USA            NaN
# 2                     Drama|Romance|War      NaN      USA      Not Rated
# ...

# %%
movies.shape
# Out:
# (3438, 25)

# %%
movies.columns
# Out:
# Index(['Title', 'Year', 'Genres', 'Language', 'Country', 'Content Rating',
#        'Duration', 'Aspect Ratio', 'Budget', 'Gross Earnings', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3', 'Facebook Likes - Director',
#        'Facebook Likes - Actor 1', 'Facebook Likes - Actor 2',
#        'Facebook Likes - Actor 3', 'Facebook Likes - cast Total',
#        'Facebook likes - Movie', 'Facenumber in posters', 'User Votes',
#        'Reviews by Users', 'Reviews by Crtiics', 'IMDB Score'],
#       dtype='object')

# %%
movies.describe()
# Out:
#               Year     Duration  Aspect Ratio        Budget  Gross Earnings  \
# count  3438.000000  3434.000000   3341.000000  3.201000e+03    3.014000e+03
# mean   1997.984293   108.998544      2.056537  3.941075e+07    4.492082e+07
# std      12.470263    23.883193      0.376536  2.432410e+08    6.292982e+07
# min    1916.000000     7.000000      1.180000  2.180000e+02    7.030000e+02
# 25%    1996.000000    94.000000      1.850000  6.500000e+06    5.387876e+06
# 50%    2002.000000   104.000000      1.850000  1.943000e+07    2.341684e+07
# 75%    2006.000000   119.000000      2.350000  4.000000e+07    5.788069e+07
# max    2009.000000   330.000000     16.000000  1.221550e+10    7.605058e+08
#
#        Facebook Likes - Director  Facebook Likes - Actor 1  \
# count                3438.000000               3435.000000
# mean                  745.030832               6263.029403
# std                  2929.053031              15250.115971
# ...

# %%
directors = movies.groupby(["Director"])['IMDB Score'].mean().sort_values(ascending=False)

# %%
directors
# Out:
# Director
# Charles Chaplin                     8.600
# Florian Henckel von Donnersmarck    8.500
# Majid Majidi                        8.500
# Sergio Leone                        8.475
# Moustapha Akkad                     8.400
#                                     ...
# Roger Christian                     2.400
# Alex Zamm                           2.300
# Jason Friedberg                     2.300
# Vondie Curtis-Hall                  2.100
# A. Raven Cruz                       1.900
# Name: IMDB Score, Length: 1728, dtype: float64

# %%
movies["Net Earnings"] = movies["Gross Earnings"] - movies["Budget"]

# %%
output = movies[["Title", "Budget", "Gross Earnings", "Net Earnings"]].sort_values(by="Net Earnings", ascending=False).head(20)

# %%
output
# Out:
#                                                 Title       Budget  \
# 1867                                          Avatar   237000000.0
# 1027                                         Titanic   200000000.0
# 226               Star Wars: Episode IV - A New Hope    11000000.0
# 328                       E.T. the Extra-Terrestrial    10500000.0
# 737                                    The Lion King    45000000.0
# 1281       Star Wars: Episode I - The Phantom Menace   115000000.0
# 1774                                 The Dark Knight   185000000.0
# 659                                    Jurassic Park    63000000.0
# 605                                     Finding Nemo    94000000.0
# 877                                          Shrek 2   150000000.0
# 707    The Lord of the Rings: The Return of the King    94000000.0
# 359       Star Wars: Episode VI - Return of the Jedi    32500000.0
# 709                                     Forrest Gump    55000000.0
# ...

# %%
output.plot(kind="bar", x="Title", y="Net Earnings")
# Out:
# <AxesSubplot:xlabel='Title'>

# %%
output.to_excel("output.xls")
